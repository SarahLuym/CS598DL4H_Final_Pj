# %% [markdown]
# # Set Up Code

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'CS598_DL4H'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
os.chdir(GOOGLE_DRIVE_PATH)
# Out:
# ['mimic3-benchmarks-master', 'prepare_dataset.ipynb']

# %%
# %cd mimic3-benchmarks-master
# Out:
# /content/drive/My Drive/CS598_DL4H/mimic3-benchmarks-master

# %%
# !python -m mimic3benchmark.scripts.extract_subjects mimic-iii-clinical-database-1.4 data/root/
# Out:
# START:
# 	ICUSTAY_IDs: 61532
# 	HADM_IDs: 57786
# 	SUBJECT_IDs: 46476
# REMOVE ICU TRANSFERS:
# 	ICUSTAY_IDs: 55830
# 	HADM_IDs: 52834
# 	SUBJECT_IDs: 43277
# REMOVE MULTIPLE STAYS PER ADMIT:
# 	ICUSTAY_IDs: 50186
# 	HADM_IDs: 50186
# 	SUBJECT_IDs: 41587
# REMOVE PATIENTS AGE < 18:
# 	ICUSTAY_IDs: 42276
# 	HADM_IDs: 42276
# 	SUBJECT_IDs: 33798
# Breaking up stays by subjects: 100% 33798/33798 [04:27<00:00, 126.37it/s]
# Breaking up diagnoses by subjects: 100% 33798/33798 [03:45<00:00, 150.08it/s]
# Processing CHARTEVENTS table: 100% 330712483/330712484 [3:33:58<00:00, 25759.88it/s]
# Processing LABEVENTS table: 100% 27854055/27854056 [1:38:00<00:00, 4736.93it/s]
# Processing OUTPUTEVENTS table: 100% 4349218/4349219 [21:00<00:00, 3450.59it/s]

# %%
# !python -m mimic3benchmark.scripts.validate_events data/root/
# Out:
# Namespace(subjects_root_path='data/root/')
# Iterating over subjects:   7% 2371/32968 [30:19<5:24:59,  1.57it/s]/content/drive/MyDrive/CS598_DL4H/mimic3-benchmarks-master/mimic3benchmark/scripts/validate_events.py:47: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   events_df = pd.read_csv(os.path.join(args.subjects_root_path, subject, 'events.csv'), index_col=False,
# Iterating over subjects:  18% 6071/32968 [1:05:05<4:19:46,  1.73it/s]/content/drive/MyDrive/CS598_DL4H/mimic3-benchmarks-master/mimic3benchmark/scripts/validate_events.py:47: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   events_df = pd.read_csv(os.path.join(args.subjects_root_path, subject, 'events.csv'), index_col=False,
# ...

# %%
# !python -m mimic3benchmark.scripts.extract_episodes_from_subjects data/root/
# Out:
# Streaming output truncated to the last 5000 lines.
#   labels[l] = 0
# /content/drive/MyDrive/CS598_DL4H/mimic3-benchmarks-master/mimic3benchmark/preprocessing.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# /content/drive/MyDrive/CS598_DL4H/mimic3-benchmarks-master/mimic3benchmark/preprocessing.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   labels[l] = 0
# ...

# %%
# !python -m mimic3benchmark.scripts.split_train_and_test data/root/

# %%
# !python -m mimic3benchmark.scripts.create_in_hospital_mortality data/root/ data/hospital-mortality/
# Out:
# Iterating over patients in test: 100% 5070/5070 [1:11:54<00:00,  1.18it/s]
# Number of created samples: 3236
# Iterating over patients in train:   4% 1173/28728 [17:50<7:11:05,  1.07it/s]
# 	(no events in ICU)  19097 episode1_timeseries.csv
# Iterating over patients in train:  13% 3778/28728 [55:09<6:03:35,  1.14it/s]
# 	(no events in ICU)  19872 episode1_timeseries.csv
# Iterating over patients in train:  16% 4493/28728 [1:05:15<7:57:03,  1.18s/it]
# 	(no events in ICU)  14469 episode1_timeseries.csv
# Iterating over patients in train:  16% 4576/28728 [1:06:24<3:50:09,  1.75it/s]
# 	(no events in ICU)  18350 episode1_timeseries.csv
# Iterating over patients in train:  20% 5813/28728 [1:24:29<5:36:53,  1.13it/s]
# 	(no events in ICU)  14219 episode1_timeseries.csv
# Iterating over patients in train:  20% 5874/28728 [1:25:14<5:03:38,  1.25it/s]
# 	(length of stay is missing) 10128 episode1_timeseries.csv
# Iterating over patients in train:  31% 8764/28728 [2:07:00<3:39:45,  1.51it/s]
# ...

# %%
# !python -m mimic3models.split_train_val data/hospital-mortality
